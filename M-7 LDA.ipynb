# %%
import pandas as pd
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# data=["India is my country",
#       "Tomorrow is IPL final match between RCM & Punjab",
#       "Deep learning is subset for ML.",
#       "Tesla is the first Automated car."]

# news=fetch_20newsgroups()
# data=news.data

# %%
df=pd.read_csv("articles.csv")

# %%
df
# Out:
#                   author claps  reading_time  \
# 0             Justin Lee  8.3K            11
# 1            Conor Dewey  1.4K             7
# 2       William Koehrsen  2.8K            11
# 3           Gant Laborde  1.3K             7
# 4       Emmanuel Ameisen   935            11
# ..                   ...   ...           ...
# 332       Daniel Simmons  3.4K             8
# 333  Eugenio Culurciello  2.8K            13
# 334           Devin Soni  5.8K             4
# 335      Carlos E. Perez  3.9K             7
# 336      Nityesh Agarwal  2.4K            13
#
#                                                   link  \
# 0    https://medium.com/swlh/chatbots-were-the-next...
# 1    https://towardsdatascience.com/python-for-data...
# 2    https://towardsdatascience.com/automated-featu...
# 3    https://medium.freecodecamp.org/machine-learni...
# 4    https://blog.insightdatascience.com/reinforcem...
# ..                                                 ...
# ...

# %%
x=df.isnull().sum()

# %%
print(x)
# Out:
# author          0
# claps           0
# reading_time    0
# link            0
# title           0
# text            0
# dtype: int64

# %%
abc=CountVectorizer(stop_words='english')

# %%
x=abc.fit_transform(df)

# %%
topic=5
lda=LatentDirichletAllocation(n_components=topic,random_state=42)
lda.fit(x)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
words=10
feature= abc.get_feature_names_out()

def display (model,feature,words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic{topic_idx +1 }:")
        print(", ".join([feature[i] for i in topic.argsort ()[:-words - 1:-1]]))

display(lda,feature,words)
# Out:
# Topic1:
# text, author, reading_time, claps, title, link
# Topic2:
# claps, author, reading_time, text, link, title
# Topic3:
# reading_time, author, claps, title, text, link
# Topic4:
# link, author, reading_time, text, claps, title
# Topic5:
# title, author, reading_time, link, claps, text
